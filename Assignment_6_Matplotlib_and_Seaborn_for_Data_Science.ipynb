# %% [markdown]
# <a href="https://colab.research.google.com/github/hmdredwan/Co-Lab/blob/main/Assignment_6_Matplotlib_and_Seaborn_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Datasets

# %%
# from google.colab import files
# uploaded=files.upload()
# gym = pd.read_csv('gym_membership.csv')
from google.colab import drive
drive.mount('/content/drive')
import warnings
warnings.filterwarnings('ignore')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gym=pd.read_csv('/content/drive/MyDrive/Assignments_Colab/Datasets/gym_membership.csv')

# %%
print(gym.head())
print(gym.shape)
print(gym.columns.tolist())
# Out:
#    id  gender   birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  4/18/1997   27        Premium               4
# 1   2  Female  9/18/1977   47       Standard               3
# 2   3    Male  3/30/1983   41        Premium               1
# 3   4    Male  4/12/1980   44        Premium               3
# 4   5    Male  9/10/1980   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                         NaN
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
#dataframe description
print("\n Dataframe description")
print(gym.describe())
# Out:
#  Dataframe description
#                 id          Age  visit_per_week  avg_time_in_gym
# count  1000.000000  1000.000000     1000.000000      1000.000000
# mean    500.500000    30.604000        2.682000       105.260000
# std     288.819436    10.817958        1.241941        43.557177
# min       1.000000    12.000000        1.000000        30.000000
# 25%     250.750000    21.000000        2.000000        67.000000
# 50%     500.500000    30.000000        3.000000       104.000000
# 75%     750.250000    40.000000        3.000000       143.000000
# max    1000.000000    49.000000        5.000000       180.000000

# %%
#Basic Dataframe information
print("\n Dataframe information")
print(gym.info())
# Out:
#  Dataframe information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1000 non-null   int64
#  1   gender                 1000 non-null   object
#  2   birthday               1000 non-null   object
#  3   Age                    1000 non-null   int64
#  4   abonoment_type         1000 non-null   object
#  5   visit_per_week         1000 non-null   int64
#  6   days_per_week          1000 non-null   object
#  7   attend_group_lesson    1000 non-null   bool
#  8   fav_group_lesson       503 non-null    object
#  9   avg_time_check_in      1000 non-null   object
#  10  avg_time_check_out     1000 non-null   object
#  11  avg_time_in_gym        1000 non-null   int64
#  12  drink_abo              1000 non-null   bool
#  13  fav_drink              496 non-null    object
# ...

# %%
#Last 5 rows of datasets
print(gym.tail())
#check datatypes
print(gym.dtypes)
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 995   996  Female   9/22/1984   40       Standard               3
# 996   997  Female  11/19/2008   15       Standard               3
# 997   998    Male   10/5/1984   40       Standard               2
# 998   999    Male   2/22/2001   23       Standard               4
# 999  1000  Female    5/7/2006   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 995       Thu, Tue, Wed                False              NaN
# 996       Fri, Mon, Sun                 True     XCore, Zumba
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 995          20:56:00           22:42:00              106      False
# ...

# %% [markdown]
# # 1. Bar Chart of gym membership types

# %%
abdomen_count=gym['abonoment_type'].value_counts()
print(abdomen_count)
#for displaying this information in bar chart
plt.bar(['Standard','Premium'],abdomen_count,color=['blue','yellow'])
plt.grid(True,which="both",linestyle="--",linewidth=0.7,alpha=1)
plt.xlabel('Gym Membership Types')
plt.ylabel('Count')
plt.title('Bar Chart of Gym Membership Types')
plt.show()
# Out:
# abonoment_type
# Standard    507
# Premium     493
# Name: count, dtype: int64

# %% [markdown]
# #2. Histogram of time in gym

# %%
plt.hist(gym['avg_time_in_gym'],bins=20)
plt.title("Histogram of Time in Gym")
plt.xlabel("Time in Gym")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #3. Scatter plot: Age vs visits per week

# %%
from pickle import FALSE
#sample=gym.head(500)
plt.scatter(gym['Age'],gym['visit_per_week'])
plt.title("Scatter Plot : Age vs Visits per week")
plt.xlabel("Age")
plt.ylabel("Visits per week")
plt.show()
# Out:
# 0      Mon, Sat, Tue, Wed
# 1           Mon, Sat, Wed
# 2                     Sat
# 3           Sat, Tue, Wed
# 4                Thu, Wed
#               ...
# 495                   Sun
# 496              Sat, Sun
# 497    Mon, Sat, Tue, Wed
# 498         Mon, Sat, Thu
# 499         Mon, Sun, Wed
# Name: days_per_week, Length: 500, dtype: object

# %% [markdown]
# #1. Box plot: Gender vs Age

# %%
sns.boxplot(data=gym,x='gender',y='Age')
plt.grid(True,which='both',linestyle='--',alpha=0.7)
plt.title("Box Plot: Gender vs Age")
plt.xlabel("Gender")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# #2. Count plot: Days per week

# %%
sns.countplot(data=gym,x='visit_per_week')
plt.grid(True,which='both',linestyle='--',alpha=0.7)
plt.title("Count Plot: Days per week")
plt.xlabel("Visits per week")
plt.ylabel("Count")
plt.show()

sns.countplot(data=gym,x='days_per_week')
plt.grid(True,which='both',linestyle='--',alpha=0.7)
plt.title("Count Plot: Days per week")
plt.xlabel("Days per week")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #Bar plot: Average visits by membership type

# %%
sns.barplot(data=gym,x='abonoment_type',y='visit_per_week')
plt.grid(True,which='both',linestyle='--',alpha=0.7)
plt.title("Bar Plot: Average visits by membership type")
plt.xlabel("Membership Type")
plt.ylabel("Average Visits")
plt.show()
